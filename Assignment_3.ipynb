# %%
1. Why are functions advantageous to have in your programs?
A. Functions reduces the duplicate code and also it makes the programs shorter,easier to read and update

2. When does the code in a function run: when it's specified or when it's called?
A. Function runs when its called

3. What statement creates a function?
A. def is a keyword used for creating the function

4. What is the difference between a function and a function call?
A. A function is a block of code that performs an operation and returns the result. A function call is the code used to pass control to the function.

5. How many global scopes are there in a Python program? How many local scopes?
A. There is only global scope in the entire program,The scope will remain till it gets terminated.
   local scope is defined by the local variable in which it is defined in the function,Its scope remains only in that defined function,Likewise we can have any number of local scopes

6. What happens to variables in a local scope when the function call returns?
A. variables defined in a local scope remain in that function,when the function call returns,it retains the value and we can use any number of times calling functions.

7. What is the concept of a return value? Is it possible to have a return value in an expression?
A. A return statement ends the function execution and returns the result,Yes we can return value in a expression when used explicitly.
eg.return_42() + 5
47

8. If a function does not have a return statement, what is the return value of a call to that function?
A. The function returns None.

9. How do you make a function variable refer to the global variable?
A. By using global keyword

10. What is the data type of None?
A. None defines null value or no value at all

11. What does the sentence import areallyourpetsnamederic do?
A. It imports th module named areallyourpetsnamederic.

12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
A. spam.bacon()

13. What can you do to save a programme from crashing if it encounters an error?
A. By using simple checks

14. What is the purpose of the try clause? What is the purpose of the except clause?
A. try and except clause are both used for catching and handling exceptions,Python executes the code in try block normally and in except block it checks for exceptions caused in preceeding try block.
